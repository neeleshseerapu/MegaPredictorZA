# %%
import pandas as pd
from pandas.io.xml import preprocess_data
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder #LabelEncoder usually for target data
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('cleandex.csv').set_index("No")

# %%
features = list(df.columns[2:7]) + list(df.columns[14:-1])
numerical = [features[i] for i in [1, 2, 7, 8, 11, 12, 13, 14, 15, 16, 17, 18]]
categorical = [features[i] for i in [0, 3, 4, 9, 10]]
target = "Mega"

# %%
print(features)
print(numerical)
print(categorical)
# Out:
# ['Generation', 'Height', 'Weight', 'Type1', 'Type2', 'Egg_Group1', 'Egg_Group2', 'Get_Rate', 'Base_Experience', 'Experience_Type', 'Category', 'HP', 'Attack', 'Defense', 'SP_Attack', 'SP_Defense', 'Speed', 'Total', 'Regional']
# ['Height', 'Weight', 'Get_Rate', 'Base_Experience', 'HP', 'Attack', 'Defense', 'SP_Attack', 'SP_Defense', 'Speed', 'Total', 'Regional']
# ['Generation', 'Type1', 'Type2', 'Egg_Group1', 'Egg_Group2', 'Experience_Type', 'Category']

# %%
X, Y = df[features], df[target]
trainX, testX, trainY, testY = train_test_split(X, Y, train_size=0.7, random_state=115)

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(), numerical),
        ("cat", OneHotEncoder(), categorical)
    ]
)

# %%
pipe = make_pipeline(
preprocessor,
    LogisticRegression() # classifier
)

# %%
pipe.fit(trainX, trainY)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Height', 'Weight',
#                                                    'Get_Rate',
#                                                    'Base_Experience', 'HP',
#                                                    'Attack', 'Defense',
#                                                    'SP_Attack', 'SP_Defense',
#                                                    'Speed', 'Total',
#                                                    'Regional']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Generation', 'Type1',
#                                                    'Type2', 'Egg_Group1',
#                                                    'Egg_Group2',
#                                                    'Experience_Type',
# ...

# %%
accuracy_score(pipe.predict(testX), testY)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 accuracy_score(pipe.predict(testX), testY)
#
# File ~/PycharmProjects/ML/.venv/lib/python3.11/site-packages/sklearn/pipeline.py:786, in Pipeline.predict(self, X, **params)
#     784 if not _routing_enabled():
#     785     for _, name, transform in self._iter(with_final=False):
# --> 786         Xt = transform.transform(Xt)
#     787     return self.steps[-1][1].predict(Xt, **params)
#     789 # metadata routing enabled
#
# File ~/PycharmProjects/ML/.venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
# ...

# %%
df.loc[[289]][features] # two brackets, makes the row a row in a 2d space

# %%
pipe.predict(df.loc[[289]][features]) # make series 260 a dataframe, and then get its feature to make it 2d

# %%
df[target].shape

# %%
pd.concat([df[features], df[target]], axis=1)

# %%
for i in range(1,len(df.index)):
    if (int(pipe.predict(df.loc[[i+1]][features])[0])==1 and df.loc[i+1]["Mega"]==0):
        print(df.index[i], df.loc[i+1]["Original_Name"])

# %%
#Instead, I believe it would be a better idea to train on megas, and see which non-megas fit the criteria.
